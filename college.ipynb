# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("CollegeData.csv", delimiter=",", encoding='utf-8')

# %%
df.describe()
# Out:
#        Total Students          Male        Female          CGPA  \
# count    50000.000000  50000.000000  50000.000000  50000.000000
# mean     15522.357440   7747.061900   3555.550780      8.705289
# std       8366.792001   4188.406336   5892.297104      1.053363
# min       1001.000000    500.000000 -13917.000000      4.001559
# 25%       8272.750000   4111.000000    527.000000      7.980137
# 50%      15506.500000   7756.000000   3744.000000      8.806043
# 75%      22768.250000  11360.000000   7786.000000      9.652321
# max      29999.000000  14999.000000  14999.000000     10.000000
#
#        Annual Family Income  Research Papers Published  Placement Rate  \
# count          5.000000e+04               50000.000000    50000.000000
# mean           2.611606e+06                  24.472300       82.335352
# std            1.387889e+06                  14.458858       11.475691
# min            2.000040e+05                   0.000000       60.000000
# ...

# %%
df.tail(5)
# Out:
#        College ID       Country  Total Students   Male  Female      CGPA  \
# 49995  College 93         India           14676  10771    3905  8.335598
# 49996  College 48         Japan           21908  10682    6820  8.490003
# 49997  College 67  South Africa           17263  11035    6228  5.979781
# 49998  College 54           USA           11371  10233    1138  7.714894
# 49999  College 16         China           20867  10643   10224  8.861043
#
#        Annual Family Income                   Branch     Sports  \
# 49995               3151197        Civil Engineering    Cricket
# 49996               3060006                  Physics      Chess
# 49997               1519563     Chemical Engineering  Athletics
# 49998               2429788   Mechanical Engineering   Swimming
# 49999               3962086  Business Administration     Tennis
#
#        Research Papers Published  Placement Rate  Faculty Count
# 49995                         20           65.61            596
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# China           5052
# South Africa    5052
# Switzerland     5025
# Australia       5018
# Singapore       5013
# Japan           4991
# USA             4985
# Canada          4974
# UK              4945
# India           4945
# Name: count, dtype: int64

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Total Students'}>,
#         <Axes: title={'center': 'Male'}>,
#         <Axes: title={'center': 'Female'}>],
#        [<Axes: title={'center': 'CGPA'}>,
#         <Axes: title={'center': 'Annual Family Income'}>,
#         <Axes: title={'center': 'Research Papers Published'}>],
#        [<Axes: title={'center': 'Placement Rate'}>,
#         <Axes: title={'center': 'Faculty Count'}>, <Axes: >]],
#       dtype=object)

# %%
print(df[df['Female'] < 0])
# Out:
#         College ID      Country  Total Students   Male  Female      CGPA  \
# 4       College 61       Canada           10236  13339   -3103  8.560567
# 6       College 83           UK            8135  11111   -2976  6.935854
# 10      College 88    Australia            3850  12936   -9086  7.874765
# 11     College 100        Japan            2873   8467   -5594  7.967944
# 15      College 53    Australia            9806  12405   -2599  8.531940
# ...            ...          ...             ...    ...     ...       ...
# 49959   College 42  Switzerland            1535  13576  -12041  6.937371
# 49969   College 79    Australia           11213  13443   -2230  8.139287
# 49971   College 78    Singapore            3646  14186  -10540  6.766305
# 49981   College 82       Canada            3284  11319   -8035  7.273230
# 49983   College 59          USA            3759   7370   -3611  8.536683
#
#        Annual Family Income                   Branch      Sports  \
# ...

# %%
# df['Female'] = df['Female'].apply(lambda x: x if x >= 0 else np.nan)
# print(df[df['Female'] < 0])
median_value = df[df['Female'] >= 0]['Female'].median()
df['Female'] = df['Female'].apply(lambda x: x if x >= 0 else median_value)
print(df[df['Female'] < 0])
# Out:
# Empty DataFrame
# Columns: [College ID, Country, Total Students, Male, Female, CGPA, Annual Family Income, Branch, Sports, Research Papers Published, Placement Rate, Faculty Count]
# Index: []

# %%
df.describe()
# Out:
#        Total Students          Male        Female          CGPA  \
# count    50000.000000  50000.000000  50000.000000  50000.000000
# mean     15522.357440   7747.061900   5897.774760      8.705289
# std       8366.792001   4188.406336   3438.503536      1.053363
# min       1001.000000    500.000000      0.000000      4.001559
# 25%       8272.750000   4111.000000   3475.000000      7.980137
# 50%      15506.500000   7756.000000   5450.000000      8.806043
# 75%      22768.250000  11360.000000   7786.000000      9.652321
# max      29999.000000  14999.000000  14999.000000     10.000000
#
#        Annual Family Income  Research Papers Published  Placement Rate  \
# count          5.000000e+04               50000.000000    50000.000000
# mean           2.611606e+06                  24.472300       82.335352
# std            1.387889e+06                  14.458858       11.475691
# min            2.000040e+05                   0.000000       60.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   College ID                 50000 non-null  object
#  1   Country                    50000 non-null  object
#  2   Total Students             50000 non-null  int64
#  3   Male                       50000 non-null  int64
#  4   Female                     50000 non-null  float64
#  5   CGPA                       50000 non-null  float64
#  6   Annual Family Income       50000 non-null  int64
#  7   Branch                     50000 non-null  object
#  8   Sports                     50000 non-null  object
#  9   Research Papers Published  50000 non-null  int64
#  10  Placement Rate             50000 non-null  float64
#  11  Faculty Count              50000 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 4.6+ MB

# %%
df['Female'] = df['Female'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   College ID                 50000 non-null  object
#  1   Country                    50000 non-null  object
#  2   Total Students             50000 non-null  int64
#  3   Male                       50000 non-null  int64
#  4   Female                     50000 non-null  int64
#  5   CGPA                       50000 non-null  float64
#  6   Annual Family Income       50000 non-null  int64
#  7   Branch                     50000 non-null  object
#  8   Sports                     50000 non-null  object
#  9   Research Papers Published  50000 non-null  int64
#  10  Placement Rate             50000 non-null  float64
#  11  Faculty Count              50000 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 4.6+ MB

# %%
df.hist('Female')
# Out:
# array([[<Axes: title={'center': 'Female'}>]], dtype=object)

# %%
df.hist('Male')
# Out:
# array([[<Axes: title={'center': 'Male'}>]], dtype=object)

# %%
df_numeric = df.select_dtypes(include=['number'])  # Selectează doar coloanele numerice
df_numeric.corr()
# Out:
#                            Total Students      Male    Female      CGPA  \
# Total Students                   1.000000 -0.003421  0.374999 -0.008510
# Male                            -0.003421  1.000000 -0.097104  0.007645
# Female                           0.374999 -0.097104  1.000000  0.001367
# CGPA                            -0.008510  0.007645  0.001367  1.000000
# Annual Family Income            -0.003158  0.004538 -0.002095  0.564398
# Research Papers Published        0.005903  0.000281  0.002882  0.002838
# Placement Rate                  -0.000608  0.000615 -0.001784  0.002571
# Faculty Count                    0.541926 -0.001763  0.202577 -0.002699
#
#                            Annual Family Income  Research Papers Published  \
# Total Students                        -0.003158                   0.005903
# Male                                   0.004538                   0.000281
# Female                                -0.002095                   0.002882
# ...

# %%
df.hist('Faculty Count')
# Out:
# array([[<Axes: title={'center': 'Faculty Count'}>]], dtype=object)
